# %%
import pandas as pd
import requests


url = "https://raw.githubusercontent.com/fababa/Data-Analyst-Portfolio---IBM-Data-Analyst-and-Azure-AI-Fundamentals/main/Python-Projects/Web-Scraping/most_canada_friendly_car_brand.json"


response = requests.get(url)

if response.status_code == 200:
  try:
    data = response.json()
    post_data = data[0]["data"]["children"][0]["data"]
    comments = []
    def extract_comments(comment_list):
      for comment in comment_list:
        if comment["kind"] == "t1":
          comment_data = comment["data"]
          comments.append({
              "post_title": post_data.get("title"),
              "post_author": post_data.get("author"),
              "comment_author": comment_data.get("author"),
              "comment": comment_data.get("body"),
              "score": comment_data.get("score"),
              "created_utc": comment_data.get("created_utc")
              })
          replies = comment_data.get("replies")
          if isinstance(replies, dict):
            extract_comments(replies["data"]["children"])
    extract_comments(data[1]["data"]["children"])
    comments_df = pd.DataFrame(comments)
    print(comments_df.head())
    comments_df.to_csv("reddit_canada_friendly_car_brand_comments.csv", index=False)
    print("Scraping completed and CSV file saved.")
  except ValueError:
        print("Response is not valid JSON.")
        print(response.text[:500])

else:
    print("Failed to scrape Reddit page.")
    print("Status code:", response.status_code)
# Out:
#                         post_title post_author   comment_author  \
# 0  Most Canada friendly car brand?     JonnyDL    AutoModerator
# 1  Most Canada friendly car brand?     JonnyDL    SvenBubbleman
# 2  Most Canada friendly car brand?     JonnyDL    SiphonTheFern
# 3  Most Canada friendly car brand?     JonnyDL   gimmickypuppet
# 4  Most Canada friendly car brand?     JonnyDL  Parker_Hardison
#
#                                              comment  score  created_utc
# 0  Thanks for your post on /r/BuyCanadian! Make s...      1   1780446378
# 1  As others have said Toyota and Honda both make...    186   1780447963
# 2  And completely stopped selling the models made...     42   1780482301
# 3  RIP The Ascent. We would’ve considered it when...      5   1780497385
# 4  Yup. I just got a C-HR (which Toyota and Subar...      4   1780653364
# Scraping completed and CSV file saved.
